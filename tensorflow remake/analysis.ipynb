# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
metrics = pd.read_csv('metrics.csv')
metrics.head()
# Out:
#    CrossEntropyLoss  accuracy  accuracy_class_0  accuracy_class_1  \
# 0          0.614767  0.840833          0.923518          0.931474
# 1          0.298933  0.915083          0.965727          0.969149
# 2          0.248581  0.929217          0.968766          0.971373
# 3          0.214082  0.939200          0.971298          0.974785
# 4          0.187816  0.946317          0.974168          0.976120
#
#    accuracy_class_2  accuracy_class_3  accuracy_class_4  accuracy_class_5  \
# 0          0.807486          0.839178          0.849880          0.691570
# 1          0.884357          0.882564          0.926395          0.865707
# 2          0.907184          0.900995          0.935296          0.899650
# 3          0.923800          0.912575          0.942143          0.920679
# 4          0.935717          0.924156          0.948477          0.931378
#
#    accuracy_class_6  accuracy_class_7  ...  val_accuracy_class_0  \
# ...

# %%
len(metrics)
# Out:
# 50

# %%
metric = 'CrossEntropyLoss'

# %%
plt.plot(metrics[[metric, f'val_{metric}']], label=[metric, f'val_{metric}'])
plt.xlabel('Epoch')
plt.ylabel('Score')
plt.legend()

# %%
metric = 'accuracy'

# %%
plt.plot(metrics[[metric, f'val_{metric}']], label=[metric, f'val_{metric}'])
plt.xlabel('Epoch')
plt.ylabel('Score')
plt.legend()

# %%
metric = "accuracy_class_"

# %%
metric = [metric+str(i) for i in range(10)] 
plt.plot(metrics[metric], label=metric)
plt.xlabel('Epoch')
plt.ylabel('Score')
plt.legend()

# %%
metric = 'val_accuracy_class_'

# %%
metric = [metric+str(i) for i in range(10)] 
plt.plot(metrics[metric], label=metric)
plt.xlabel('Epoch')
plt.ylabel('Score')
plt.legend()
